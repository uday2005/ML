# %% [markdown]
# # 1

# %%
user_input_str = input("Enter a list of integers: ")

# Convert the input string into a list of integers

numbers = [int(num) for num in user_input_str.split()]

# Print the list in reverse order
reversed_list = numbers[::-1]
print(f"Reversed list: {reversed_list}")

# Calculate and print the sum and average
list_sum = sum(numbers)
print(f"Sum: {list_sum}")

if len(numbers) > 0:
    list_average = list_sum / len(numbers)
    print(f"Average: {list_average}")
else:
    print("Average: N/A (list is empty)")

# Remove all even numbers 
odd_numbers = [num for num in numbers if num % 2 != 0]
print(f"List without even numbers: {odd_numbers}")
# Out:
# Reversed list: [5, 5, 5, 5]
# Sum: 20
# Average: 5.0
# List without even numbers: [5, 5, 5, 5]

# %% [markdown]
# # 2

# %%
def count_vowels_and_consonants(text):
    vowels = "aeiou"
    vowel_count = 0
    consonant_count = 0

    for char in text.lower():
        if char.isalpha():
            if char in vowels:
                vowel_count += 1
            else:
                consonant_count += 1
    
    return vowel_count, consonant_count

# Example Usage
input_string = "Hello World"
vowels, consonants = count_vowels_and_consonants(input_string)

print(f"Vowels: {vowels}")
print(f"Consonants: {consonants}")
# Out:
# Vowels: 3
# Consonants: 7

# %% [markdown]
# # 3

# %%
number_str = input("Enter a number: ")
number = int(number_str)

# Check if the number is positive, negative, or zero
if number > 0:
    print("Number is positive.")
elif number < 0:
    print("Number is negative.")
else:
    print("Number is zero.")

    # Check if the number is even or odd
if number % 2 == 0:
    print("Number is even.")
else:
    print("Number is odd.")
# Out:
# Number is positive.
# Number is odd.

# %% [markdown]
# # 4

# %%
file_name = "notes.txt"

with open(file_name, 'w') as f:
    f.write("Python is fun.\n")
    f.write("Let's learn it well!\n")

print("\nReading contents from the file:")
with open(file_name, 'r') as f:
    content = f.read()
    print(content)
# Out:
# Reading contents from the file:
# Python is fun.
# Let's learn it well!

# %%
student_marks = {}

print("Enter the names and marks for 5 students.")
for i in range(5):
    while True:
        name = input(f"Enter name for student {i+1}: ")
        break
            
    while True:
            marks = int(input(f"Enter marks for {name}: "))
            break
    
    student_marks[name] = marks

print("\nStudent Marks:", student_marks)

# Displays the name(s) of the student(s) with the highest marks
if student_marks:
    max_mark = max(student_marks.values())
    top_scorers = [name for name, mark in student_marks.items() if mark == max_mark]
    print("Top Scorer(s):", ", ".join(top_scorers))
# Out:
# Enter the names and marks for 5 students.
#
# Student Marks: {'uday': 6, 'kusum': 20, 'ansu': 3, 'yuva': 34, 'udat': 4}
# Top Scorer(s): yuva

# %% [markdown]
# # Chess Basics

# %% [markdown]
# 1. 64 squares.
# 2. 16 16 both side names are 2rook 1queen 1king 2bishop 8pawn 2knights
# 3. white queen starts from d1 square.

# %% [markdown]
#    1. A bishop moves any number of unoccupied squares diagonally. Each bishop is restricted to squares of one color (either light or dark) for the entire game.
# 2.  The Knight is the only piece that can jump over other pieces.
# 3. A pawn captures one square diagonally forward. While it moves straight forward, its capture is a diagonal move

# %% [markdown]
# 1. Castling invloves king with one rooks and the king moves two square towards the rook and rook goes to the squarefrom that king is moved.
# 2. I din't knew it so it is nust google answers. <br>
#    En passant (French for "in passing") is a special pawn capture. It can only occur immediately after an enemy pawn advances two squares from its starting position. If your pawn is positioned to have captured it had it only moved one square, you can capture the enemy pawn "in passing" by moving your pawn to the square the enemy pawn skipped over. This option is only available on the very next tur
# 3. When a pawn reaches the furthest rank , it undergoes promotion. The player must immediately exchange the pawn for a new queen, rook, bishop, or knight of the same color

# %% [markdown]
# 1.  main objective of a chess game is to checkmate the opponent's king.
# 2.
#     a. Check: A situation where a king is under direct attack by one or more opponent's pieces. The player must make a move to get their king out of check. <br>
#     b. Checkmate: A situation where a king is in check and there is no legal move to get out of check. The player who is checkmated loses the game.
# 3. A stalemate is a situation where the player whose turn it is to move has no legal moves, but their king is not in check. A stalemate ends the game in a draw.
