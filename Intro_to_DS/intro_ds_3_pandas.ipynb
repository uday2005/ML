# %%
import pandas as pd    
import numpy as np

# %%
wh = pd.read_csv("https://raw.githubusercontent.com/csmastersUH/data_analysis_with_python_2020/master/kumpula-weather-2017.csv")
wh.head()    # Head print the first 5 rows.
# Out:
#    Year  m  d   Time Time zone  Precipitation amount (mm)  Snow depth (cm)  \
# 0  2017  1  1  00:00       UTC                       -1.0             -1.0
# 1  2017  1  2  00:00       UTC                        4.4             -1.0
# 2  2017  1  3  00:00       UTC                        6.6              7.0
# 3  2017  1  4  00:00       UTC                       -1.0             13.0
# 4  2017  1  5  00:00       UTC                       -1.0             10.0
#
#    Air temperature (degC)
# 0                     0.6
# 1                    -3.9
# 2                    -6.5
# 3                   -12.8
# 4                   -17.8

# %%
wh["Snow depth (cm)"].head()
# Out:
# 0    -1.0
# 1    -1.0
# 2     7.0
# 3    13.0
# 4    10.0
# Name: Snow depth (cm), dtype: float64

# %%
wh["Air temperature (degC)"].mean()
# Out:
# np.float64(6.527123287671233)

# %%
wh.drop("Time zone", axis=1).head()    
# Return a copy with one column removed, the original DataFrame stays intact
# Out:
#    Year  m  d   Time  Precipitation amount (mm)  Snow depth (cm)  \
# 0  2017  1  1  00:00                       -1.0             -1.0
# 1  2017  1  2  00:00                        4.4             -1.0
# 2  2017  1  3  00:00                        6.6              7.0
# 3  2017  1  4  00:00                       -1.0             13.0
# 4  2017  1  5  00:00                       -1.0             10.0
#
#    Air temperature (degC)
# 0                     0.6
# 1                    -3.9
# 2                    -6.5
# 3                   -12.8
# 4                   -17.8

# %% [markdown]
# In case you want to modify the original DataFrame, you can either assign <br>
# the result to the original DataFrame, or use the inplace parameter of the drop method. <br>
# Many of the modifying methods of the DataFrame have the inplace parameter.

# %%
wh["Rainy"] = wh["Precipitation amount (mm)"] > 5
wh.head()
# Out:
#    Year  m  d   Time Time zone  Precipitation amount (mm)  Snow depth (cm)  \
# 0  2017  1  1  00:00       UTC                       -1.0             -1.0
# 1  2017  1  2  00:00       UTC                        4.4             -1.0
# 2  2017  1  3  00:00       UTC                        6.6              7.0
# 3  2017  1  4  00:00       UTC                       -1.0             13.0
# 4  2017  1  5  00:00       UTC                       -1.0             10.0
#
#    Air temperature (degC)  Rainy
# 0                     0.6  False
# 1                    -3.9  False
# 2                    -6.5   True
# 3                   -12.8  False
# 4                   -17.8  False

# %%
# One can turn any one-dimensional iterable into a Series, which is a one-dimensional data structure

s=pd.Series([1, 4, 5, 2, 5, 2])
s.name = "Grades"  # we can give name to the series
s
print(f"Name: {s.name}, dtype: {s.dtype}, size: {s.size}")

s[1] # idnexing works here also 
print(s[1])
s2 = s[[0,5]]
print(s2)

t = s[-2:]
print(t)
t[4] # t[0] will give error as stil the t[4] is indices

print(s2.values) #The values as a NumPy array are accessible via the values attribute:

print(s2.index) #And the indices are available through the index attribute
# Out:
# Name: Grades, dtype: int64, size: 6
# 4
# 0    1
# 5    2
# Name: Grades, dtype: int64
# 4    5
# 5    2
# Name: Grades, dtype: int64
# [1 2]
# Index([0, 5], dtype='int64')

# %%
# The index is not simply a NumPy array, but a data structure that allows fast access to the elements. 
# The indices need not be integers, as the next example shows

s3=pd.Series([1, 4, 5, 2, 5, 2], index=list("abcdef"))
print(s3)
print(s3.index)
print(s3['b'])
print(s3['b':'e'])

# can we still acess the numpy series using the numpy style implicit integer index.
# s3[1] # This is confusing 

#so to remove ambiguity we introduced the loc and iloc method 

s4 = pd.Series(["Jack", "Jones", "James"], index=[1,2,3])
s4

#  For this ambiguity Pandas offers attributes loc and iloc. The attributes loc 
# always uses the explicit index, while the attribute iloc always uses the implicit integer index

# print(s4[1])
print(s4.loc[1])
print(s4.iloc[1])
# Out:
# a    1
# b    4
# c    5
# d    2
# e    5
# f    2
# dtype: int64
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')
# 4
# b    4
# c    5
# d    2
# e    5
# dtype: int64
# Jack
# Jones

# %%
df=pd.DataFrame(np.random.randn(2,3), columns=["First", "Second", "Third"], index=["a", "b"])
df
# Out:
#       First   Second     Third
# a -0.486971 -0.62612 -0.751321
# b -0.637528 -0.23354 -1.220802

# %%
df=pd.DataFrame(np.random.randn(2,3), columns=["First", "Second", "Third"], index=["a", "b"])
df
# Out:
#       First    Second     Third
# a -0.573980  0.063704  1.507601
# b  0.702752 -0.199552  0.994569

# %%
df.index
df.columns
# Out:
# Index(['First', 'Second', 'Third'], dtype='object')

# %%
s1 = pd.Series([1,2,3])
s2 = pd.Series([4,5,6], name="b")

pd.DataFrame(s1, columns=["a"])
pd.DataFrame(s2)

# If using multiple columns, then they must be given as the dictionary, 
# whose keys give the column names and values are the actual column content

pd.DataFrame({"a":s1 , "b":s2})
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df=pd.DataFrame([{"Wage" : 1000, "Name" : "Jack", "Age" : 21}, {"Wage" : 1500, "Name" : "John", "Age" : 29}])
df = pd.DataFrame([[1000, "Jack", 21], [1500, "John", 29]], columns=["Wage", "Name", "Age"])
df
# Out:
#    Wage  Name  Age
# 0  1000  Jack   21
# 1  1500  John   29

# %%
df["Wage"]

df[["Wage" , "Name"]]

df[0:1]

df["Wage"][0:1]
# Out:
# 0    1000
# Name: Wage, dtype: int64

# %%
# The difference between loc and iloc attributes is 
# that the former uses explicit indices and the latter uses the implicit integer indices

print(df.loc[1, "Wage"]) # loc is what we defined explicit index
print(df.iloc[-1,-1])

df.loc[1, ["Name", "Wage"]]
# Out:
# 1500
# 29
# Name    John
# Wage    1500
# Name: 1, dtype: object

# %%
wh = pd.read_csv("https://raw.githubusercontent.com/csmastersUH/data_analysis_with_python_2020/master/kumpula-weather-2017.csv")
wh.head()
# Out:
#    Year  m  d   Time Time zone  Precipitation amount (mm)  Snow depth (cm)  \
# 0  2017  1  1  00:00       UTC                       -1.0             -1.0
# 1  2017  1  2  00:00       UTC                        4.4             -1.0
# 2  2017  1  3  00:00       UTC                        6.6              7.0
# 3  2017  1  4  00:00       UTC                       -1.0             13.0
# 4  2017  1  5  00:00       UTC                       -1.0             10.0
#
#    Air temperature (degC)
# 0                     0.6
# 1                    -3.9
# 2                    -6.5
# 3                   -12.8
# 4                   -17.8

# %%
h2 = wh.drop(["Year", "m", "d"], axis=1)
h2.mean(numeric_only=True)
# As here Time zone is not numerical so it will give type error 
# by mentioning numeric_only = True we say calculate only whose
# contain the numeric value
# Out:
# Precipitation amount (mm)    1.966301
# Snow depth (cm)              0.966480
# Air temperature (degC)       6.527123
# dtype: float64

# %%
wh.describe()
# Out:
#          Year           m           d  Precipitation amount (mm)  \
# count   365.0  365.000000  365.000000                 365.000000
# mean   2017.0    6.526027   15.720548                   1.966301
# std       0.0    3.452584    8.808321                   4.858423
# min    2017.0    1.000000    1.000000                  -1.000000
# 25%    2017.0    4.000000    8.000000                  -1.000000
# 50%    2017.0    7.000000   16.000000                   0.200000
# 75%    2017.0   10.000000   23.000000                   2.700000
# max    2017.0   12.000000   31.000000                  35.000000
#
#        Snow depth (cm)  Air temperature (degC)
# count       358.000000              365.000000
# mean          0.966480                6.527123
# std           3.717472                7.183934
# min          -1.000000              -17.800000
# 25%          -1.000000                1.200000
# 50%          -1.000000                4.800000
# 75%           0.000000               12.900000
# ...

# %%
wh["Snow depth (cm)"].unique()
# Out:
# array([-1.,  7., 13., 10., 12.,  9.,  8.,  5.,  6.,  4.,  3., 15., 14.,
#         2., nan,  0.])

# %%
# Note that only float types allow the nan value
# (in Python, NumPy or Pandas). 
# So, if we try to create an integer series with missing values,
# its dtype gets promoted to float

pd.Series([1,3,2])
pd.Series([1,3,2,np.nan])
# Out:
# 0    1.0
# 1    3.0
# 2    2.0
# 3    NaN
# dtype: float64

# %%
wh.isnull()
# Out:
#       Year      m      d   Time  Time zone  Precipitation amount (mm)  \
# 0    False  False  False  False      False                      False
# 1    False  False  False  False      False                      False
# 2    False  False  False  False      False                      False
# 3    False  False  False  False      False                      False
# 4    False  False  False  False      False                      False
# ..     ...    ...    ...    ...        ...                        ...
# 360  False  False  False  False      False                      False
# 361  False  False  False  False      False                      False
# 362  False  False  False  False      False                      False
# 363  False  False  False  False      False                      False
# 364  False  False  False  False      False                      False
#
#      Snow depth (cm)  Air temperature (degC)
# 0              False                   False
# ...

# %%
# This is not very useful as we cannot directly use the 
# mask to index the DataFrame. We can, however, combine
# it with the any method to find out all the rows
# that contain at least one missing value

wh[wh.isnull().any(axis=1)]
# Out:
#      Year   m   d   Time Time zone  Precipitation amount (mm)  \
# 74   2017   3  16  00:00       UTC                        1.8
# 163  2017   6  13  00:00       UTC                        0.6
# 308  2017  11   5  00:00       UTC                        0.2
# 309  2017  11   6  00:00       UTC                        2.0
# 313  2017  11  10  00:00       UTC                        3.6
# 321  2017  11  18  00:00       UTC                       11.3
# 328  2017  11  25  00:00       UTC                        8.5
#
#      Snow depth (cm)  Air temperature (degC)
# 74               NaN                     3.4
# 163              NaN                    12.6
# 308              NaN                     8.4
# 309              NaN                     7.5
# 313              NaN                     7.2
# 321              NaN                     5.9
# 328              NaN                     4.2

# %%
# the notnull method works conversively to the isnull method.

wh.dropna().shape # default axis is 0
wh.dropna(axis = 1).shape
# Out:
# (365, 7)

# %%
# The fillna method allows to fill the missing values with some constant or interpolated values.
#  The method parameter can be:

# None: use the given positional parameter as the constant to fill missing values with
# ffill: use the previous value to fill the current value
# bfill: use the next value to fill the current value

# %%
wh = wh.ffill()
wh[wh.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Year, m, d, Time, Time zone, Precipitation amount (mm), Snow depth (cm), Air temperature (degC)]
# Index: []

# %%
pd.Series(["1","2"]).map(int)   
pd.Series([1,2]).map(str)  

pd.to_numeric(pd.Series([1,1.0]), downcast="integer")

pd.to_numeric(pd.Series([1,"a"]), errors="coerce")      # conversion error produces Nan
# Out:
# 0    1.0
# 1    NaN
# dtype: float64

# %%
pd.Series([1,2]).astype(str)                            # works for a single series
# Out:
# 0    1
# 1    2
# dtype: object

# %%
df = pd.DataFrame({"a": [1,2,3], "b" : [4,5,6], "c" : [7,8,9]})
print(df.dtypes)
print(df)

df.astype(float)                       # Convert all columns
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#      a    b    c
# 0  1.0  4.0  7.0
# 1  2.0  5.0  8.0
# 2  3.0  6.0  9.0

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# --- Step 1: Create a synthetic dataset ---
# We'll create 50 positive and 50 negative reviews.
# For simplicity, we'll use a few template phrases and repeat them.

positive_phrases = [
    "This was a fantastic movie, I loved it.",
    "The acting was superb and the plot was engaging.",
    "A true masterpiece of cinema, absolutely brilliant.",
    "I would highly recommend this film to everyone.",
    "An amazing and unforgettable experience."
]

negative_phrases = [
    "A terrible film, I hated every minute of it.",
    "The plot was boring and the acting was awful.",
    "A complete waste of time and money.",
    "I would not recommend this movie to anyone.",
    "A disappointing and predictable story."
]

# Create 50 positive and 50 negative reviews
reviews = [positive_phrases[i % 5] for i in range(50)] + \
          [negative_phrases[i % 5] for i in range(50)]
sentiments = ['positive'] * 50 + ['negative'] * 50

# Create a Pandas DataFrame
df = pd.DataFrame({
    'Review': reviews,
    'Sentiment': sentiments
})


print(df)

# appears in both so does not make sense as it will not distinguish them 
nonsence_words = ['the', 'is', 'and', 'movie', 'film','i','a','this','plot']
vectorizer = CountVectorizer(max_features=500, stop_words=nonsence_words)
# countvectorizer converts all words to lowercase before processing so stop_words
# should be lower case letters

X = df['Review']
y = df['Sentiment']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2, stratify=y
)
# stratify ensures that the split will keep the same proportion of 
# class in both the tarining and test sets as original data.

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec =  vectorizer.transform(X_test)


model = MultinomialNB()

model.fit(X_train_vec ,y_train)

y_pred = model.predict(X_test_vec)

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuarcy : {accuracy:.2f}")
# Out:
#                                                Review Sentiment
# 0             This was a fantastic movie, I loved it.  positive
# 1    The acting was superb and the plot was engaging.  positive
# 2   A true masterpiece of cinema, absolutely brill...  positive
# 3     I would highly recommend this film to everyone.  positive
# 4            An amazing and unforgettable experience.  positive
# ..                                                ...       ...
# 95       A terrible film, I hated every minute of it.  negative
# 96      The plot was boring and the acting was awful.  negative
# 97                A complete waste of time and money.  negative
# 98        I would not recommend this movie to anyone.  negative
# 99             A disappointing and predictable story.  negative
#
# [100 rows x 2 columns]
# Accuarcy : 1.00

# %%
def predict_review_sentiment(model, vectorizer, review: str):
    review_vec = vectorizer.transform([review])
    # transform exepects a iterable so we make it a list 
    predict = model.predict(review_vec)
    return predict 

ll = predict_review_sentiment(model,vectorizer,"A disappointing and predictable story.")
print(ll)
print(ll[0])
# Out:
# ['negative']
# negative

# %% [markdown]
# // problem 5

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

good_feedback = [
    "Excellent quality and fast shipping, I love this product.",
    "The item works perfectly and exceeded my expectations.",
    "Great value for the price, very satisfied with my purchase.",
    "Customer service was fantastic and the product is top-notch.",
    "I would highly recommend this to anyone looking for a reliable item."
]

bad_feedback = [
    "The product arrived broken and the quality is terrible.",
    "Very slow delivery and the item does not work as advertised.",
    "A complete waste of money, I am very disappointed.",
    "Poor customer support and the product feels cheap.",
    "I would not buy this again, a very negative experience."
]

# Create 100 text samples (50 good, 50 bad)
texts = [good_feedback[i % 5] for i in range(50)] + \
        [bad_feedback[i % 5] for i in range(50)]
labels = ['good'] * 50 + ['bad'] * 50

# Create a DataFrame
df = pd.DataFrame({
    'Feedback': texts,
    'Label': labels
})

vectorizer = TfidfVectorizer(max_features=300, stop_words='english')
# stop words  english will by default choose the words which usually do not help in distinguish

X = df['Feedback']
y = df['Label']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=2, stratify=y
)
# stratify ensures that the split will keep the same proportion of 
# class in both the tarining and test sets as original data.

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec =  vectorizer.transform(X_test)

model = LogisticRegression()

model.fit(X_train_vec ,y_train)

y_pred = model.predict(X_test_vec)

report = classification_report(y_test, y_pred, target_names=['bad', 'good'])

print(report)

def text_preprocess_vectorize(texts: list, vectorizer):
    vectorized_matrix = vectorizer.transform(texts)
    return vectorized_matrix

ll = text_preprocess_vectorize(list("The product arrived broken and the quality is terrible.") , vectorizer)
print(ll)
# Out:
#               precision    recall  f1-score   support
#
#          bad       1.00      1.00      1.00        13
#         good       1.00      1.00      1.00        12
#
#     accuracy                           1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (55, 43)>

# %%
a=np.array([1,3,4])
b=np.array([2,2,7])
c = a < b
print(c)

print(c.any())
print(c.all())

print(c.sum())
# Out:
# [ True False  True]
# True
# False
# 2

# %%
import pandas as pd
a=pd.read_csv("https://raw.githubusercontent.com/csmastersUH/data_analysis_with_python_2020/master/kumpula-weather-2017.csv")['Air temperature (degC)'].values

# %%
a
# Out:
# array([  0.6,  -3.9,  -6.5, -12.8, -17.8, -17.8,  -3.8,  -0.5,   0.5,
#          1.7,  -1.6,  -2.8,   1.1,   0.8,  -2.8,  -4.2,  -3.5,   1.1,
#          1.6,  -0.6,  -1.8,   1. ,   0.1,  -2.2,  -3.8,   1.9,   1.6,
#          0.8,   0.6,   1. ,   0.2,  -0.6,  -0.8,  -0.2,   0.4,  -2.5,
#         -7.3, -12.1,  -8.8, -10.1,  -8.3,  -5.4,  -2.7,   1.5,   4.4,
#          0. ,   0.5,   1.5,   1.9,   2.2,   0.4,  -2.5,  -4.6,  -0.7,
#         -5.3,  -5.6,  -2. ,  -2.3,   2.1,   1.5,   1.5,   0.9,  -1.8,
#         -4.2,  -4.2,  -2.9,   0.2,   1.2,   1.4,   2.2,  -0.9,   0.6,
#          0.6,   3.8,   3.4,   2. ,   1.6,   0.6,   0.2,   1.6,   2.3,
#          2.5,   0.5,   1.9,   4.8,   6.6,   2.4,   0.4,  -0.4,   0.2,
#          1.5,   4.3,   3. ,   3.8,   3.3,   4.7,   4.1,   3.3,   3.7,
#          6. ,   4.3,   1.8,   1.2,  -0.5,  -1.4,  -1.7,   0.6,   0.3,
#          1.2,   2.5,   5.7,   3.1,   2.9,   3.6,   2.8,   3.2,   4.4,
# ...

# %%
print("Number of days with the temperature below zero", np.sum(a < 0))
print(np.sum((a>0)& (a<10)))

c= a>0
print(c[:10])
print(a[c])

a[~c] = 0 # Zeros out the neagtive temperaures.
print(a)
# Out:
# Number of days with the temperature below zero 0
# 185
# [ True False False False False False False False  True  True]
# [ 0.6  0.5  1.7  1.1  0.8  1.1  1.6  1.   0.1  1.9  1.6  0.8  0.6  1.
#   0.2  0.4  1.5  4.4  0.5  1.5  1.9  2.2  0.4  2.1  1.5  1.5  0.9  0.2
#   1.2  1.4  2.2  0.6  0.6  3.8  3.4  2.   1.6  0.6  0.2  1.6  2.3  2.5
#   0.5  1.9  4.8  6.6  2.4  0.4  0.2  1.5  4.3  3.   3.8  3.3  4.7  4.1
#   3.3  3.7  6.   4.3  1.8  1.2  0.6  0.3  1.2  2.5  5.7  3.1  2.9  3.6
#   2.8  3.2  4.4  4.1  2.3  2.2  7.6  9.4  9.2  6.7 10.1 11.1  6.1  4.4
#   1.5  1.5  2.9  5.1  7.5  9.8  9.   7.3  9.4 11.2 16.1 16.9 14.7 14.6
#  13.3 12.4 14.1 14.1  9.6 13.2 14.1  9.6 10.8  6.5  6.2 10.   9.9 10.4
#  14.5 16.4 12.3 14.  16.3 16.8 12.6 12.6 14.8 15.1 18.4 19.3 16.9 17.8
#  12.7 12.4 12.2 10.8 12.9 14.  13.5 13.7 15.3 16.3 17.2 14.1 16.4 14.5
#  14.1 14.  11.5 14.7 16.1 17.4 18.  16.8 16.8 14.7 15.3 16.7 18.  15.4
#  15.  13.7 14.6 15.8 15.6 16.9 15.7 16.1 17.2 19.  19.1 17.8 18.3 17.8
# ...

# %%
a = np.array([[1, 3, 4, 2],
              [2, 2, 1, 2]])
print(a.shape)


n , p = a.shape
m = p//2
# print(a[:,0:m])
cond = np.sum(a[:,0:m]) > np.sum(a[:,m:p])# this will compute for all
#rows i a matrix to compute for each row we do axis= 1
# 1+3+2+2
cond = np.sum(a[:,0:m],axis=1) > np.sum(a[:,m:p],axis=1)
#1 + 3
print(a[cond])
# Out:
# (2, 4)
# [[2 2 1 2]]

# %% [markdown]
# n NumPy, the axis parameter refers to which dimension to collapse/sum along:
#
# axis=0 → Sum down the rows (collapse the row dimension)
# axis=1 → Sum across the columns (collapse the column dimension)
# Example:
# With axis=0 (sum down rows):
#
# a = np.array([[1, 2, 3, 4],
#               [5, 6, 7, 8]])
#
# np.sum(a, axis=0)  # = [6, 8, 10, 12]
# * This sums column-wise: [1+5, 2+6, 3+7, 4+8]
#
# np.sum(a, axis=1)  # = [10, 26]
# * This sums row-wise: [1+2+3+4, 5+6+7+8]

# %%
np.random.seed(0)
a=np.random.randint(0, 20,20)
a2=np.array([a[2], a[5], a[7]])
print(a)
print(a2)

idx=[2,5,7]           # List of indices
print(a[idx])         # In fancy indexing in place of a single index, we can provide a list of indices
print(a[[2,5,7]]) 

a[idx] = -1
print(a)

# a[:,[0,2]]
# Out:
# [12 15  0  3  3  7  9 19 18  4  6 12  1  6  7 14 17  5 13  8]
# [ 0  7 19]
# [ 0  7 19]
# [ 0  7 19]
# [12 15 -1  3  3 -1  9 -1 18  4  6 12  1  6  7 14 17  5 13  8]

# %%
a=np.array([2,1,4,3,5])
print(np.sort(a))          # Does not modify the argument
print(a)

a.sort()      # modifies the argument.
print(a)

b=np.random.randint(0,10, (4,4))
print(b)

np.sort(b,axis=0)  # sort each column

np.sort(b, axis=1)           # Sort each row
# Out:
# [1 2 3 4 5]
# [2 1 4 3 5]
# [1 2 3 4 5]
# [[8 4 1 4]
#  [9 8 1 1]
#  [7 9 9 3]
#  [6 7 2 0]]
# array([[1, 4, 4, 8],
#        [1, 1, 8, 9],
#        [3, 7, 9, 9],
#        [0, 2, 6, 7]], dtype=int32)

# %%
# A related operation is the argsort function. Which doesn't sort the elements, but returns the indices of the sorted elements

a=np.array([23,12,47,35,59])
print("Array a:", a)
idx = np.argsort(a)
print("Indices:", idx)

print(a[idx])
# Out:
# Array a: [23 12 47 35 59]
# Indices: [1 0 3 2 4]
# [12 23 35 47 59]

# %%
a = np.array([[1, 3, 4, 2],
              [2, 2, 1, 1]])
c = -1
unique_vals ,counts = np.unique(a[:,c],return_counts= True)
freq_order = np.argsort(-counts) #This will give list in order of index

result = []
for idx in freq_order:
    val = unique_vals[idx]
    mask  = a[:,c] == val
    result.extend(a[mask])

print(counts)
# Out:
# [1 1]

# %%
# np.vstack() is specifically designed for combining arrays 
# of potentially different row counts, while np.array() expects uniform shapes.

def most_frequent_first(a, c):

    unique_vals ,counts = np.unique(a[:,c],return_counts= True)
    freq_order = np.argsort(-counts) #This will give list in order of index

    result = []
    for idx in freq_order:
        val = unique_vals[idx]
        mask  = a[:,c] == val
        result.append(a[mask])

    
    return np.vstack(result)

# %%
s=np.array([[1, 6, 7],
 [7, 8, 1],
 [5, 9, 8]])
print("Original matrix:", s, sep="\n")
s_inv = np.linalg.inv(s)
print("Inverted matrix:", s_inv, sep="\n")
print("Matrix product:", s @ s_inv, sep="\n")                            # This should be pretty close to the identity matrix np.eye(3)
print("Matrix product the other way:", s_inv @ s, sep="\n")                            # Same here
# Out:
# Original matrix:
# [[1 6 7]
#  [7 8 1]
#  [5 9 8]]
# Inverted matrix:
# [[-0.61111111 -0.16666667  0.55555556]
#  [ 0.56666667  0.3        -0.53333333]
#  [-0.25555556 -0.23333333  0.37777778]]
# Matrix product:
# [[ 1.00000000e+00 -2.77555756e-17  3.33066907e-16]
#  [ 7.21644966e-16  1.00000000e+00  1.11022302e-16]
#  [ 0.00000000e+00 -2.22044605e-16  1.00000000e+00]]
# Matrix product the other way:
# [[ 1.00000000e+00 -5.55111512e-16  0.00000000e+00]
#  [-2.22044605e-16  1.00000000e+00  8.88178420e-16]
#  [ 1.11022302e-16 -3.33066907e-16  1.00000000e+00]]

# %%
x=np.array([1,4,2])

x=np.array([1,4,2])
y = s @ x                  # Transforms x to y
print(y)

print(s_inv @ y)           # Transforms y back to x
# Out:
# [39 41 57]
# [1. 4. 2.]

# %%
#!/usr/bin/env python3

import functools
import numpy as np
def matrix_power(a, n):
    m = a.shape[0]
    if(n< 0):
        inv_matr = np.linalg.inv(a)
        n = -1 * n
        # mat_power = np.linalg.matrix_power(inv_matr,n)
        mat_power = functools.reduce(np.dot,(inv_matr for _ in range(n)))
    
    elif(n==0):
        return np.eye(m)
    else:
        # mat_power = np.linalg.matrix_power(a,n)
        mat_power = functools.reduce(np.dot,(a for _ in range(n)))
    
    return mat_power

def main():
    return

if __name__ == "__main__":
    main()

# %%
import scipy.stats
import numpy as np

def load():
    import pandas as pd
    return pd.read_csv("src/iris.csv").drop('species', axis=1).values


def lengths():
    df = load()
    val = scipy.stats.pearsonr(df[:,0],df[:,2])
    return val[0]

def correlations():
    data = load()
    return np.corrcoef(data.T)
    
def main():
    print(lengths())
    print(correlations())

# didn't understood this will later.

# %%
#!/usr/bin/python3

import numpy as np

def meeting_planes(a1, b1, c1, a2, b2, c2, a3, b3, c3):
    A = np.array([[b1,a1,-1],[b2,a2,-1],[b3,a3,-1]])
    b = np.array([-c1,-c2,-c3])
    x = np.linalg.solve(A,b)
    return x

def main():
    a1=1
    b1=4
    c1=5
    a2=3
    b2=2
    c2=1
    a3=2
    b3=4
    c3=1

    x, y, z = meeting_planes(a1, b1, c1, a2, b2, c2, a3, b3, c3)
    print(f"Planes meet at x={x}, y={y} and z={z}")

if __name__ == "__main__":
    main()
# Out:
# Planes meet at x=2.000000000000001, y=4.000000000000001 and z=17.000000000000004

# %%
def almost_meeting_lines(a1, b1, a2, b2):
    A = np.array([[a1, -1], [a2, -1]])
    b = np.array([-b1, -b2])
    
    solution, residuals, rank, s = np.linalg.lstsq(A, b, rcond=None)
    x, y = solution
    
    # Check if solution is exact (residuals are very small or empty)
        # Exact solution only if:
    # 1. Full rank (rank == 2) - unique solution exists
    # 2. Small or no residuals - solution fits well
    exact = (rank == 2) and (len(residuals) == 0 or (len(residuals) > 0 and residuals[0] < 1e-10))
    
    return (x, y), exact

# Didn't understood
