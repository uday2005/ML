# %%
# !pip3 install -U ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\rajud\appdata\local\programs\python\python311\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\rajud\appdata\local\programs\python\python311\lib\site-packages (from ucimlrepo) (2.3.0)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\rajud\appdata\local\programs\python\python311\lib\site-packages (from ucimlrepo) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\rajud\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rajud\appdata\roaming\python\python311\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajud\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rajud\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rajud\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
from ucimlrepo import fetch_ucirepo, list_available_datasets

  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets 
  
# metadata 
print(heart_disease.metadata) 
  
# variable information 
print(heart_disease.variables)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from ucimlrepo import fetch_ucirepo, list_available_datasets
#       4 # fetch dataset
#       5 heart_disease = fetch_ucirepo(id=45)
#
# ModuleNotFoundError: No module named 'ucimlrepo'
